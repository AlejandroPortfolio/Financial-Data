# %%
import requests
import pandas as pd
import json

# %%
#Default link to get and paste into text file
#https://data.sec.gov/api/xbrl/companyfacts/CIK0001318605.json

# %%
j = open('jsonformatter.txt')
data = json.load(j)

# %%
data['facts']['us-gaap']['DepreciationAndAmortization']
# Out:
# {'label': 'Depreciation, Depletion and Amortization, Nonproduction',
#  'description': 'The current period expense charged against earnings on long-lived, physical assets not used in production, and which are not intended for resale, to allocate or recognize the cost of such assets over their useful lives; or to record the reduction in book value of an intangible asset over the benefit period of such asset; or to reflect consumption during the period of an asset that is not used in production.',
#  'units': {'USD': [{'start': '2009-01-01',
#     'end': '2009-12-31',
#     'val': 6940000,
#     'accn': '0001193125-12-137560',
#     'fy': 2011,
#     'fp': 'FY',
#     'form': '10-K/A',
#     'filed': '2012-03-28',
#     'frame': 'CY2009'},
#    {'start': '2009-01-01',
#     'end': '2009-12-31',
#     'val': 6940000,
#     'accn': '0001193125-12-081990',
#     'fy': 2011,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2012-02-27'},
#    {'start': '2010-01-01',
# ...
